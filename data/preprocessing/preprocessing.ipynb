# %%
import pandas as pd

csv_name = "Gebäude nach Gemeinde.csv"

df = pd.read_csv(csv_name, sep=",", encoding='ISO-8859-1')

print(df.head())
# print(df.describe())
# Out:
#                   Gemeinde  Einfamilienhäuser Vor 1919 erbaut  \
# 0                  Schweiz                             121795
# 1     0001 Aeugst am Albis                                 46
# 2  0002 Affoltern am Albis                                132
# 3          0003 Bonstetten                                 40
# 4     0004 Hausen am Albis                                164
#
#    Einfamilienhäuser Zwischen 1919 und 1945 erbaut  \
# 0                                           105523
# 1                                                8
# 2                                              110
# 3                                               21
# 4                                                8
#
#    Einfamilienhäuser Zwischen 1946 und 1960 erbaut  \
# 0                                           111636
# 1                                               12
# 2                                              123
# 3                                               79
# ...
