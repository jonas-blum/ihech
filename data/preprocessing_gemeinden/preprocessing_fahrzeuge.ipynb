# %%
import pandas as pd
import numpy as np

csv_file = "2019_neue_fahrzeuge.csv"

df = pd.read_csv(csv_file, sep=",", encoding='ISO-8859-1')

df = df.rename(columns={"2019": "Anzahl"})
print(df.head())
pivot_df = df.pivot_table(index="Gemeinde", columns=["Fahrzeuggruppe", "Treibstoff"], values="Anzahl")

pivot_df.reset_index(inplace=True)
pivot_df[['Gemeindenummer', 'Gemeinde']] = pivot_df['Gemeinde'].str.split(' ', n=1, expand=True)


pivot_df.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in pivot_df.columns.values]

pivot_df.set_index('Gemeindenummer_', inplace=True)


pivot_df.to_csv("2019_neue_fahrzeuge_cleaned.csv", encoding='ISO-8859-1')
# Out:
#             Gemeinde Fahrzeuggruppe                         Treibstoff  Anzahl
# 0  1 Aeugst am Albis  Personenwagen                             Benzin      48
# 1  1 Aeugst am Albis  Personenwagen                             Diesel      11
# 2  1 Aeugst am Albis  Personenwagen   Benzin-elektrisch: Normal-Hybrid       7
# 3  1 Aeugst am Albis  Personenwagen  Benzin-elektrisch: Plug-in-Hybrid       2
# 4  1 Aeugst am Albis  Personenwagen   Diesel-elektrisch: Normal-Hybrid       0
#                        Gemeinde_  Anhänger_Anderer  Anhänger_Benzin  \
# Gemeindenummer_
# 1                Aeugst am Albis                 0                0
# 10                      Obfelden                 0                0
# 100                       Stadel                 0                0
# 1001               Doppleschwand                 0                0
# 1002                   Entlebuch                 0                0
#
#                  Anhänger_Benzin-elektrisch: Normal-Hybrid  \
# Gemeindenummer_
# 1                                                        0
# 10                                                       0
# 100                                                      0
# 1001                                                     0
# 1002                                                     0
#
#                  Anhänger_Benzin-elektrisch: Plug-in-Hybrid  Anhänger_Diesel  \
# Gemeindenummer_
# 1                                                         0                0
# 10                                                        0                0
# 100                                                       0                0
# 1001                                                      0                0
# 1002                                                      0                0
#
#                  Anhänger_Diesel-elektrisch: Normal-Hybrid  \
# Gemeindenummer_
# 1                                                        0
# 10                                                       0
# 100                                                      0
# 1001                                                     0
# 1002                                                     0
#
#                  Anhänger_Diesel-elektrisch: Plug-in-Hybrid  \
# Gemeindenummer_
# 1                                                         0
# 10                                                        0
# 100                                                       0
# 1001                                                      0
# 1002                                                      0
#
#                  Anhänger_Elektrisch  Anhänger_Gas (mono- und bivalent)  ...  \
# Gemeindenummer_                                                          ...
# 1                                  0                                  0  ...
# 10                                 0                                  0  ...
# 100                                0                                  0  ...
# 1001                               0                                  0  ...
# 1002                               0                                  0  ...
#
#                  Sachentransportfahrzeuge_Benzin  \
# Gemeindenummer_
# 1                                              0
# 10                                             1
# 100                                            0
# 1001                                           0
# 1002                                           1
#
#                  Sachentransportfahrzeuge_Benzin-elektrisch: Normal-Hybrid  \
# Gemeindenummer_
# 1                                                                0
# 10                                                               0
# 100                                                              0
# 1001                                                             0
# 1002                                                             0
#
#                  Sachentransportfahrzeuge_Benzin-elektrisch: Plug-in-Hybrid  \
# Gemeindenummer_
# 1                                                                0
# 10                                                               0
# 100                                                              0
# 1001                                                             0
# 1002                                                             0
#
#                  Sachentransportfahrzeuge_Diesel  \
# Gemeindenummer_
# 1                                              1
# 10                                            15
# 100                                            3
# 1001                                           1
# 1002                                           8
#
#                  Sachentransportfahrzeuge_Diesel-elektrisch: Normal-Hybrid  \
# Gemeindenummer_
# 1                                                                0
# 10                                                               0
# 100                                                              0
# 1001                                                             0
# 1002                                                             0
#
#                  Sachentransportfahrzeuge_Diesel-elektrisch: Plug-in-Hybrid  \
# Gemeindenummer_
# 1                                                                0
# 10                                                               0
# 100                                                              0
# 1001                                                             0
# 1002                                                             0
#
#                  Sachentransportfahrzeuge_Elektrisch  \
# Gemeindenummer_
# 1                                                  0
# 10                                                 0
# 100                                                0
# 1001                                               0
# 1002                                               0
#
#                  Sachentransportfahrzeuge_Gas (mono- und bivalent)  \
# Gemeindenummer_
# 1                                                                0
# 10                                                               0
# 100                                                              0
# 1001                                                             0
# 1002                                                             0
#
#                  Sachentransportfahrzeuge_Ohne Motor  \
# Gemeindenummer_
# 1                                                  0
# 10                                                 0
# 100                                                0
# 1001                                               0
# 1002                                               0
#
#                  Sachentransportfahrzeuge_Wasserstoff
# Gemeindenummer_
# 1                                                   0
# 10                                                  0
# 100                                                 0
# 1001                                                0
# 1002                                                0
#
# [5 rows x 78 columns]
